# %% [markdown]
# <a href="https://colab.research.google.com/github/starrax/task/blob/master/tesk1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 과제 1

# %% [markdown]
# ### **언어** ###

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26aeafd3-e85c-440d-9256-02797daf4061" name="files[]" multiple disabled />
#      <output id="result-26aeafd3-e85c-440d-9256-02797daf4061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
from IPython.display import Image
Image('image.png')

# %% [markdown]
# ### **음성** ###

# %%
from google.colab import files
uploaded = files.upload()

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "image1.jpg" with length 69689 bytes

# %%
from IPython.display import Image
Image('image1.jpg')

# %% [markdown]
# ### **이미지** ###

# %% [markdown]
# 얼굴인식

# %% [markdown]
# [뉴스](https://www.dailysecu.com/news/articleView.html?idxno=40211)

# %% [markdown]
# ### **자율주행** ###

# %% [markdown]
# [뉴스](http://m.biz.khan.co.kr/view.html?art_id=201702122046005)
